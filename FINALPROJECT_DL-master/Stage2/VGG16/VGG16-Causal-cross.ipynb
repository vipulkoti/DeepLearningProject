# %% [markdown]
# ### Citations -
# https://github.com/tensorflow

# %%
# Optional for Patrick's Google Drive
from google.colab import drive
drive.mount("/content/drive")
# %cd '/content/drive/MyDrive/FIN/FINALPROJECT_DL/'
# !pip install -r requirements.txt
# Out:
# Mounted at /content/drive

# %%
# Out:
# /content/drive/MyDrive/FINALPROJECT_DL_Collab

# %%
# !pip install -q kaggle

# %%
# #Configuration environment
# import os

# os.environ['KAGGLE_USERNAME'] = "vipulkoti" # username from the json file
# os.environ['KAGGLE_KEY'] = "59c15e9d2ada3bedf6072af79f596e65" # key from the json file

# %%
# !kaggle datasets download -d sayanf/flickr8k

# %%
# !pip install einops
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting einops
#   Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.6.1

# %%
import concurrent.futures
import collections
import dataclasses
import hashlib
import itertools
import json
import math
import os
import pathlib
import random
import re
import string
import time
import urllib.request

import einops
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from PIL import Image
import requests
import tqdm

import tensorflow as tf

# %% [markdown]
# Check GPU

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# ### Data preprocessing and Dataset cleanup

# %% [markdown]
# #### Download dataset from: https://www.kaggle.com/datasets/sayanf/flickr8k

# %%
image_dir_path = "./archive/Flickr8k_Dataset/"
caption_file_path = './archive/Flickr8k_text/Flickr8k.token.txt'
train_img_file_path = './archive/Flickr8k_text/Flickr_8k.trainImages.txt'
test_img_file_path = './archive/Flickr8k_text/Flickr_8k.testImages.txt'

images = os.listdir(image_dir_path)
captions_text = open(caption_file_path,'r').read()

print("Total Images in Dataset - {}\n".format(len(images)))
print("Sample Caption Details - \n{}\n".format(captions_text[:696]))

captions_dict = dict()
for line in captions_text.split('\n'):
    tokens = line.split()
    if len(line) > 2:
        image_id = tokens[0].split('#')[0]
        image_desc = ' '.join(tokens[1:])
        if image_id not in captions_dict:
            captions_dict[image_id] = list()
        captions_dict[image_id].append(image_desc)

train_images = pathlib.Path(train_img_file_path).read_text().splitlines()
train_captions = [((image_dir_path+file_name), captions_dict[file_name]) for file_name in train_images]

test_images = pathlib.Path(test_img_file_path).read_text().splitlines()
test_captions = [((image_dir_path+file_name), captions_dict[file_name]) for file_name in test_images]

train_dataset = tf.data.experimental.from_list(train_captions)
test_dataset = tf.data.experimental.from_list(test_captions)

for img_path, captions in train_dataset.take(1):
    numpy_images = img_path.numpy()
    numpy_labels = captions.numpy()
    
pic = numpy_images.decode()
label = numpy_labels
x=plt.imread(pic)
plt.imshow(x)
plt.show()
print(numpy_labels)
# Out:
# Total Images in Dataset - 8091
#
# Sample Caption Details -
# 1000268201_693b08cb0e.jpg#0	A child in a pink dress is climbing up a set of stairs in an entry way .
# 1000268201_693b08cb0e.jpg#1	A girl going into a wooden building .
# 1000268201_693b08cb0e.jpg#2	A little girl climbing into a wooden playhouse .
# 1000268201_693b08cb0e.jpg#3	A little girl climbing the stairs to her playhouse .
# 1000268201_693b08cb0e.jpg#4	A little girl in a pink dress going into a wooden cabin .
# 1001773457_577c3a7d70.jpg#0	A black dog and a spotted dog are fighting
# 1001773457_577c3a7d70.jpg#1	A black dog and a tri-colored dog playing with each other on the road .
# 1001773457_577c3a7d70.jpg#2	A black dog and a white dog with brown spots are staring at each other in the street .
# [b'A black dog is running after a white dog in the snow .'
#  b'Black dog chasing brown dog through snow'
#  b'Two dogs chase each other across the snowy ground .'
#  b'Two dogs play together in the snow .'
#  b'Two dogs running through a low lying body of water .']

# %% [markdown]
# ### Pre-process Images (Using pre-Trained MobileNetV3Small)
#
# `include_top=False` returns the model without the final classification layer, as we need feature vector.

# %%
# IMAGE_SHAPE=(224, 224, 3)
# mobilenet = tf.keras.applications.MobileNetV3Small(
#     input_shape=IMAGE_SHAPE,
#     include_top=False,
#     include_preprocessing=True)
# mobilenet.trainable=False

# %%
# IMAGE_SHAPE=(299, 299, 3)
# mobilenet = tf.keras.applications.inception_v3(
#     input_shape=IMAGE_SHAPE,
#     include_top=False,
#     include_preprocessing=True,
#     weights='imagenet')
# mobilenet.trainable=False

# %%
IMAGE_SHAPE=(224, 224, 3)
mobilenet = tf.keras.applications.VGG16(weights='imagenet',
    input_shape=IMAGE_SHAPE,
    include_top=False,)
mobilenet.trainable=False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 3s 0us/step

# %% [markdown]
# Load an image and resize it for the model:

# %%
def imageLoadResize(img_path):
    img = tf.io.read_file(img_path)
    img = tf.io.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMAGE_SHAPE[:-1])
    return img

# %%
# def load_image(image_path):
#     img = tf.io.read_file(image_path)
#     img = tf.image.decode_jpeg(img, channels=3)
#     img = tf.image.resize(img, (299, 299))
#     img = tf.keras.applications.inception_v3.preprocess_input(img)
#     return img, image_path

# %%
# image_model = tf.keras.applications.InceptionV3(include_top=False, weights='imagenet')
# new_input = image_model.input
# hidden_layer = image_model.layers[-1].output
# image_features_extract_model = tf.keras.Model(new_input, hidden_layer)

# %%
# test_img = load_image(pic)
# print(test_img)
# # print(image_features_extract_model(test_img))

# %%
# from keras.preprocessing import image
# from keras.applications.vgg16 import VGG16
# from keras.applications.vgg16 import preprocess_input
# import numpy as np

# model = VGG16(weights='imagenet', include_top=False)
# # model.summary()

# img_path = pic
# img = tf.io.read_file(img_path)
# img = tf.image.decode_jpeg(img, channels=3)
# img = tf.image.resize(img, (224, 224))
# img_data = preprocess_input(img)
# p

# vgg16_feature = model.predict(img_data)

# print(vgg16_feature.shape)

# %% [markdown]
# Feature Vector of image

# %%
test_img = imageLoadResize(pic)[tf.newaxis, :]
print(test_img.shape)
print(mobilenet(test_img).shape)
# Out:
# (1, 224, 224, 3)
# (1, 7, 7, 512)

# %%
#### Reference Code
# def preprocess_image(img_path):
#     image = tf.io.read_file(img_path)
#     image = tf.image.decode_jpeg(image, channels=3)
#     # preprocess all the images to the same size, i.e, 299×299
#     image = tf.image.resize(image, (299, 299))
#     image = tf.keras.applications.inception_v3.preprocess_input(image)
#     return image, img_path

# cnn_model = tf.keras.applications.InceptionV3(include_top=False)
# cnn_input = cnn_model.input
# cnn_hidden_layer = cnn_model.layers[-1].output

#### Reference code

# %% [markdown]
# ### Pre Process Text (Using tensorflow/keras provided functions)
#
# Basic Text clean-up to convert all text to lower case and remove punctuations
# Creating Vocabulary with limited words; Caption Tokenizer and padding

# %%
def standardize(s):
  s = tf.strings.lower(s)
  s = tf.strings.regex_replace(s, f'[{re.escape(string.punctuation)}]', '')
  s = tf.strings.join(['[START]', s, '[END]'], separator=' ')
  return s

# %%
vocabulary_size = 5000
tokenizer = tf.keras.layers.TextVectorization(
    max_tokens=vocabulary_size,
    standardize=standardize,
    ragged=True)

# %%
tokenizer.adapt(train_dataset.map(lambda fp,txt: txt).unbatch().batch(1024))

# %%
tokenizer.get_vocabulary()[:10]
# Out:
# ['', '[UNK]', 'a', '[START]', '[END]', 'in', 'the', 'on', 'is', 'and']

# %%
t = tokenizer([['a cat is sitting on a dog'], ['a robot is dancing']])
t
# Out:
# <tf.RaggedTensor [[3, 2, 655, 8, 49, 7, 2, 10, 4], [3, 2, 1937, 8, 326, 4]]>

# %%
word_to_index = tf.keras.layers.StringLookup(
    mask_token="",
    vocabulary=tokenizer.get_vocabulary())

index_to_word = tf.keras.layers.StringLookup(
    mask_token="",
    vocabulary=tokenizer.get_vocabulary(),
    invert=True)

w = index_to_word(t)

tf.strings.reduce_join(w, separator=' ', axis=-1).numpy()
# Out:
# array([b'[START] a cat is sitting on a dog [END]',
#        b'[START] a robot is dancing [END]'], dtype=object)

# %% [markdown]
# Below function makes (image,caption) pair from 1:5 to 1:1

# %%
def match_shapes(images, captions):
  caption_shape = einops.parse_shape(captions, 'b c')
  captions = einops.rearrange(captions, 'b c -> (b c)')
  images = einops.repeat(
      images, 'b ... -> (b c) ...',
      c = caption_shape['c'])
  return images, captions

# %%
# the code below convert image and paths in 1:1 , so 32 images have 5 each captions, it truns total 160 paths (5 paths repetitive for one image) and 160 captions
for ex_paths, ex_captions in train_dataset.batch(32).take(1):
  break
print("(image,caption) is 1:5")
print('image paths:', ex_paths.shape)
print('captions:', ex_captions.shape)
# print(ex_captions)

ex_paths, ex_captions = match_shapes(images=ex_paths, captions=ex_captions)
print("\n(image,caption) is 1:1 => 32*5=160")
print('image_paths:', ex_paths.shape)
print('captions:', ex_captions.shape)
# print(ex_captions)
# Out:
# (image,caption) is 1:5
# image paths: (32,)
# captions: (32, 5)
#
# (image,caption) is 1:1 => 32*5=160
# image_paths: (160,)
# captions: (160,)

# %% [markdown]
# For caption generation, tokens are both an input and the labels, shifted by one step.
#
# Below function converts `(images, texts)` pair to an `((images, input_tokens), label_tokens)` pair

# %%
def prepare_txt(image, captions):
  tokens = tokenizer(captions)
  input_tokens = tokens[..., :-1]
  label_tokens = tokens[..., 1:]
  return (image, input_tokens), label_tokens

# %% [markdown]
# Shuffle and Batch Images, Tokenize the train and test captions

# %%
def prepare_dataset(ds, tokenizer, batch_size=32, shuffle_buffer=1000):
  ds = (ds
        .shuffle(10000)
        .map(lambda path, caption: (imageLoadResize(path), caption))
        .apply(tf.data.experimental.ignore_errors())
        .batch(batch_size))

  def to_tensor(inputs, labels):
    (images, in_token), out_token = inputs, labels
    return (images, in_token.to_tensor()), out_token.to_tensor()

  return (ds
          .map(match_shapes, tf.data.AUTOTUNE)
          .unbatch()
          .shuffle(shuffle_buffer)
          .batch(batch_size)
          .map(prepare_txt, tf.data.AUTOTUNE)
          .map(to_tensor, tf.data.AUTOTUNE)
          )

# %% [markdown]
# You could install the feature extractor in your model and train on the datasets like this:

# %%
new_train_dataset_raw = prepare_dataset(train_dataset, tokenizer)
new_train_dataset_raw.element_spec
# Out:
# WARNING:tensorflow:From <ipython-input-29-a92f5d3dc77a>:5: ignore_errors (from tensorflow.python.data.experimental.ops.error_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.ignore_errors` instead.
# ((TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None),
#   TensorSpec(shape=(None, None), dtype=tf.int64, name=None)),
#  TensorSpec(shape=(None, None), dtype=tf.int64, name=None))

# %%
new_test_dataset_raw = prepare_dataset(test_dataset, tokenizer)
new_test_dataset_raw.element_spec
# Out:
# ((TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None),
#   TensorSpec(shape=(None, None), dtype=tf.int64, name=None)),
#  TensorSpec(shape=(None, None), dtype=tf.int64, name=None))

# %% [markdown]
# ## Extract Features
# Feature extraction using CNN model and loading data in batches for training

# %%
def extract_features(ds, save_path, image_model, tokenizer, shards=10, batch_size=32):
  # Load the images and make batches.
  ds = (ds
        .map(lambda path, caption: (imageLoadResize(path), caption))
        .apply(tf.data.experimental.ignore_errors())
        .batch(batch_size))

  # Run the feature extractor on each batch
  # Don't do this in a .map, because tf.data runs on the CPU. 
  def gen():
    for (images, captions) in tqdm.tqdm(ds): 
      feature_maps = image_model(images)

      feature_maps, captions = match_shapes(feature_maps, captions)
      yield feature_maps, captions

  # Wrap the generator in a new tf.data.Dataset.
  new_ds = tf.data.Dataset.from_generator(
      gen,
      output_signature=(
          tf.TensorSpec(shape=image_model.output_shape),
          tf.TensorSpec(shape=(None,), dtype=tf.string)))

  # Apply the tokenization 
  new_ds = (new_ds
            .map(prepare_txt, tf.data.AUTOTUNE)
            .unbatch()
            .shuffle(1000))
  # Save the dataset into shard files.
  def shard_func(i, item):
    return i % shards
  new_ds.enumerate().save(save_path, shard_func=shard_func)

# %%
def load_dataset(save_path, batch_size=32, shuffle=1000, cycle_length=2):
  def custom_reader_func(datasets):
    datasets = datasets.shuffle(1000)
    return datasets.interleave(lambda x: x, cycle_length=cycle_length)
  
  ds = tf.data.Dataset.load(save_path, reader_func=custom_reader_func)

  def drop_index(i, x):
    return x

  ds = (ds
        .map(drop_index, tf.data.AUTOTUNE)
        .shuffle(shuffle)
        .padded_batch(batch_size)
        .prefetch(tf.data.AUTOTUNE))
  return ds

# %%
#not run once done, run only if different model for feature extraction
# extract_features(train_dataset, 'train_cacheVGG19', mobilenet, tokenizer)
# extract_features(test_dataset, 'test_cacheVGG19', mobilenet, tokenizer)
# Out:
# 188it [03:20,  1.06s/it]
# 32it [00:14,  2.22it/s]

# %%
new_train_dataset = load_dataset('train_cacheVGG19')
new_test_dataset = load_dataset('test_cacheVGG19')

# %% [markdown]
# ## Training Dataset
#
# Below is the detail of train tensor

# %%
new_train_dataset.element_spec
# Out:
# ((TensorSpec(shape=(None, 7, 7, 512), dtype=tf.float32, name=None),
#   TensorSpec(shape=(None, None), dtype=tf.int64, name=None)),
#  TensorSpec(shape=(None, None), dtype=tf.int64, name=None))

# %% [markdown]
# The train dataset is `(input, label)` pairs (Suitable for training with Keras).
# The `inputs` comprise pairs of `(images, input_tokens)` where the `images` is vector after feature extraction.
# The model consumes the text up to each position in the `input_tokens` and predict the next element in the `labels.

# %%
inputs, ex_labels = next(iter(new_train_dataset))
ex_img, ex_in_tok = inputs

print(f"Shape of example images: {ex_img.shape}")
print(f"Shape of example input tokens: {ex_in_tok.shape}")
print(f"Shape of example labels: {ex_labels.shape}")
# Out:
# Shape of example images: (32, 7, 7, 512)
# Shape of example input tokens: (32, 20)
# Shape of example labels: (32, 20)

# %%
# The input tokens and labels are identical, except for being offset by one step.
print(ex_in_tok[0].numpy())
print(ex_labels[0].numpy())
# Out:
# [  3   2 426  12   8  40  91  21  14  64 851   7   2 171   0   0   0   0
#    0   0]
# [  2 426  12   8  40  91  21  14  64 851   7   2 171   4   0   0   0   0
#    0   0]

# %% [markdown]
# # Continuing post Model leaving model for now

# %% [markdown]
# # ==============================================

# %% [markdown]
# # A Transformer decoder model

# %% [markdown]
# This model assumes that the pretrained image encoder is sufficient, and just focuses on building the text decoder. This tutorial uses a 2-layer Transformer-decoder.
#
# The implementations are almost identical to those in the [Transformers tutorial](https://www.tensorflow.org/text/tutorials/transformer). Refer back to it for more details.
#
# <table>
# <tr>
#   <th>The Transformer encoder and decoder.</th>
# </tr>
# <tr>
#   <td>
#    <img width=400 src="https://www.tensorflow.org/images/tutorials/transformer/Transformer-1layer-words.png"/>
#   </td>
# </tr>
# </table>

# %% [markdown]
# The model will be implemented in three main parts:
#
# 1. Input - The token embedding and positional encoding (`SeqEmbedding`).
# 1. Decoder - A stack of transformer decoder layers (`DecoderLayer`) where each contains:
#    1. A causal self attention later (`CausalSelfAttention`), where each output location can attend to the output so far.
#    1. A cross attention layer (`CrossAttention`) where each output location can attend to the input image.
#    1. A feed forward network (`FeedForward`) layer which further processes each output location independently.
# 1. Output - A multiclass-classification over the output vocabulary.

# %% [markdown]
# ### Input

# %% [markdown]
# The input text has already been split up into tokens and converted to sequences of IDs.
#
# Remember that unlike a CNN or RNN the Transformer's attention layers are invariant to the order of the sequence. Without some positional input, it just sees an unordered set not a sequence. So in addition to a simple vector embedding for each token ID, the embedding layer will also include an embedding for each position in the sequence.
#
# The `SeqEmbedding` layer defined below:
#
# - It looks up the embedding vector for each token.
# - It looks up an embedding vector for each sequence location.
# - It adds the two together.
# - It uses `mask_zero=True` to initialize the keras-masks for the model.
#
# Note: This implementation learns the position embeddings instead of using fixed embeddings like in the [Transformer tutorial](https://www.tensorflow.org/text/tutorials/transformer). Learning the embeddings is slightly less code, but doesn't generalize to longer sequences.

# %%
class SeqEmbedding(tf.keras.layers.Layer):
  def __init__(self, vocab_size, max_length, depth):
    super().__init__()
    self.pos_embedding = tf.keras.layers.Embedding(input_dim=max_length, output_dim=depth)

    self.token_embedding = tf.keras.layers.Embedding(
        input_dim=vocab_size,
        output_dim=depth,
        mask_zero=True)
    
    self.add = tf.keras.layers.Add()

  def call(self, seq):
    seq = self.token_embedding(seq) # (batch, seq, depth)

    x = tf.range(tf.shape(seq)[1])  # (seq)
    x = x[tf.newaxis, :]  # (1, seq)
    x = self.pos_embedding(x)  # (1, seq, depth)

    return self.add([seq,x])

# %% [markdown]
# ### Decoder

# %% [markdown]
# The decoder is a standard Transformer-decoder, it contains a stack of `DecoderLayers` where each contains three sublayers: a `CausalSelfAttention`, a `CrossAttention`, and a`FeedForward`. The implementations are almost identical to the [Transformer tutorial](https://www.tensorflow.org/text/tutorials/transformer), refer to it for more details.
#
# The `CausalSelfAttention` layer is below:

# %%
class CausalSelfAttention(tf.keras.layers.Layer):
  def __init__(self, **kwargs):
    super().__init__()
    self.mha = tf.keras.layers.MultiHeadAttention(**kwargs)
    # Use Add instead of + so the keras mask propagates through.
    self.add = tf.keras.layers.Add() 
    self.layernorm = tf.keras.layers.LayerNormalization()
  
  def call(self, x):
    attn = self.mha(query=x, value=x,
                    use_causal_mask=True)
    x = self.add([x, attn])
    return self.layernorm(x)

# %% [markdown]
# The `CrossAttention` layer is below. Note the use of `return_attention_scores`.

# %%
class CrossAttention(tf.keras.layers.Layer):
  def __init__(self,**kwargs):
    super().__init__()
    self.mha = tf.keras.layers.MultiHeadAttention(**kwargs)
    self.add = tf.keras.layers.Add() 
    self.layernorm = tf.keras.layers.LayerNormalization()
  
  def call(self, x, y, **kwargs):
    attn, attention_scores = self.mha(
             query=x, value=y,
             return_attention_scores=True)
    
    self.last_attention_scores = attention_scores
    # print(x)
    # print(attn)

    x = self.add([x, attn])
    # print('vip ',x)
    return self.layernorm(x)

# %%
class MultiCrossAttention(tf.keras.layers.Layer):
  def __init__(self,**kwargs):
    super().__init__()
    self.mha = tf.keras.layers.MultiHeadAttention(**kwargs)
    self.multiply = tf.keras.layers.Multiply() 
    self.layernorm = tf.keras.layers.LayerNormalization()
  
  def call(self, x, y, **kwargs):
    # print(x)
    # print(y)
    attn, attention_scores = self.mha(
             query=x, value=y,
             return_attention_scores=True)
    
    self.last_attention_scores = attention_scores

    # x = tf.reduce_sum(attn * x, axis=1)
    # if x.shape == (1,256):
    #   x = tf.expand_dims(x, 1)
    x = self.multiply([x, attn])
    
    return self.layernorm(x)

# %%
class BahdanauAttention(tf.keras.Model):
    def __init__(self, units):
        # Initialize the attention layer with two dense layers and a final dense layer that produces scalar scores
        super().__init__()
        self.W1 = tf.keras.layers.Dense(units, name='dense1')
        self.W2 = tf.keras.layers.Dense(units, name='dense2')
        self.V = tf.keras.layers.Dense(1, name='dense3')
        self.layernorm = tf.keras.layers.LayerNormalization()

    def call(self, features, hidden):
        # Compute attention scores
        # Transform the hidden state to match the shape of the features tensor
        query = tf.expand_dims(hidden, 1)
        # Project the features tensor and the query tensor onto a shared hidden space
        # The resulting key tensor has shape (batch_size, 64, units)
        key = self.W1(features)
        # The resulting value tensor has shape (batch_size, 1, units)
        value = self.W2(query)
        # Compute the scores as a dot product between the key and value tensors
        # The resulting score tensor has shape (batch_size, 64, 1)
        score = tf.matmul(tf.nn.tanh(key + value), self.V(1))

        # Compute attention weights and context vector
        # Apply softmax to the scores to obtain the attention weights
        # The resulting attention_weights tensor has shape (batch_size, 64, 1)
        attention_weights = tf.nn.softmax(score, axis=1)
        # Compute the context vector as a weighted sum of the features
        # The resulting context_vector tensor has shape (batch_size, units)
        context_vector = tf.reduce_sum(attention_weights * features, axis=1)

        # return context_vector, attention_weights
        return self.layernorm(context_vector)

# %%
#Attention notes (cleanup after implementation)

# # Attention Function
#    '''e(ij) = f(s(t-1),h(j))'''
#    ''' e(ij) = Vattn(T)*tanh(Uattn * h(j) + Wattn * s(t))'''

#    score = self.Vattn(tf.nn.tanh(self.Uattn(features) + self.Wattn(hidden_with_time_axis)))

#    # self.Uattn(features) : (64,49,512)
#    # self.Wattn(hidden_with_time_axis) : (64,1,512)
#    # tf.nn.tanh(self.Uattn(features) + self.Wattn(hidden_with_time_axis)) : (64,49,512)
#    # self.Vattn(tf.nn.tanh(self.Uattn(features) + self.Wattn(hidden_with_time_axis))) : (64,49,1) ==> score

#    # you get 1 at the last axis because you are applying score to self.Vattn
#    # Then find Probability using Softmax
#    '''attention_weights(alpha(ij)) = softmax(e(ij))'''

#    attention_weights = tf.nn.softmax(score, axis=1)

#    # attention_weights shape == (64, 49, 1)
#    # Give weights to the different pixels in the image
#    ''' C(t) = Summation(j=1 to T) (attention_weights * VGG-16 features) '''

#    context_vector = attention_weights * features
#    context_vector = tf.reduce_sum(context_vector, axis=1)

#    # Context Vector(64,256) = AttentionWeights(64,49,1) * features(64,49,256)
#    # context_vector shape after sum == (64, 256)
#    # x shape after passing through embedding == (64, 1, 256)

#    x = self.embedding(x)
#    # x shape after concatenation == (64, 1,  512)

#    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)
#    # passing the concatenated vector to the GRU

# %% [markdown]
# The `FeedForward` layer is below. Remember that a `layers.Dense` layer is applied to the last axis of the input. The input will have a shape of `(batch, sequence, channels)`, so it automatically applies pointwise across the `batch` and `sequence` axes.

# %%
class FeedForward(tf.keras.layers.Layer):
  def __init__(self, units, dropout_rate=0.1):
    super().__init__()
    self.seq = tf.keras.Sequential([
        tf.keras.layers.Dense(units=2*units, activation='relu'),
        tf.keras.layers.Dense(units=units),
        tf.keras.layers.Dropout(rate=dropout_rate),
    ])

    self.layernorm = tf.keras.layers.LayerNormalization()
  
  def call(self, x):
    x = x + self.seq(x)
    return self.layernorm(x)

# %% [markdown]
# Next arrange these three layers into a larger `DecoderLayer`. Each decoder layer applies the three smaller layers in sequence. After each sublayer the shape of `out_seq` is `(batch, sequence, channels)`. The decoder layer also returns the `attention_scores` for later visualizations.

# %%
class DecoderLayer(tf.keras.layers.Layer):
  def __init__(self, units, num_heads=1, dropout_rate=0.1):
    super().__init__()
    
    self.self_attention = CausalSelfAttention(num_heads=num_heads,
                                              key_dim=units,
                                              dropout=dropout_rate)
    self.cross_attention = CrossAttention(num_heads=num_heads,
                                          key_dim=units,
                                          dropout=dropout_rate)
    self.bhanuden_attention = BahdanauAttention(units)
    self.multi_cross_attention = MultiCrossAttention(num_heads=num_heads,
                                          key_dim=units,
                                          dropout=dropout_rate)

    self.ff = FeedForward(units=units, dropout_rate=dropout_rate)
    self.hidden = tf.zeros((32, units)) #batch size , unit
      
#CHANGE: change here for attention (Comment/Uncomment)
  def call(self, inputs, training=False):
    in_seq, out_seq = inputs
    # hidden = 

    # Text input
    out_seq = self.self_attention(out_seq)

    out_seq = self.cross_attention(out_seq, in_seq)
    # print('vip ',out_seq)
    # print('vip2 ',in_seq)

    # out_seq = self.multi_cross_attention(out_seq, in_seq)
    
    self.last_attention_scores = self.cross_attention.last_attention_scores

    # out_seq = self.bhanuden_attention(in_seq, self.hidden)

    out_seq = self.ff(out_seq)

    return out_seq

# %% [markdown]
# ### Output

# %% [markdown]
# At minimum the output layer needs a `layers.Dense` layer to generate logit-predictions for each token at each location.

# %% [markdown]
# But there are a few other features you can add to make this work a little better:
#
# 1. **Handle bad tokens**: The model will be generating text. It should
#    never generate a pad, unknown, or start token (`''`, `'[UNK]'`,
#    `'[START]'`). So set the bias for these to a large negative value.
#
#    > Note: You'll need to ignore these tokens in the loss function as well.
#
# 2. **Smart initialization**: The default initialization of a dense layer will
#   give a model that initially predicts each token with almost uniform
#   likelihood. The actual token distribution is far from uniform. The
#   optimal value for the initial bias of the output layer is the log of the
#   probability of each token. So include an `adapt` method to count the tokens
#   and set the optimal initial bias. This reduces the initial loss from the
#   entropy of the uniform distribution (`log(vocabulary_size)`) to the marginal
#   entropy of the distribution (`-p*log(p)`).

# %%
#@title
class TokenOutput(tf.keras.layers.Layer):
  def __init__(self, tokenizer, banned_tokens=('', '[UNK]', '[START]'), **kwargs):
    super().__init__()
    
    self.dense = tf.keras.layers.Dense(
        units=tokenizer.vocabulary_size(), **kwargs)
    self.tokenizer = tokenizer
    self.banned_tokens = banned_tokens

    self.bias = None

  def adapt(self, ds):
    counts = collections.Counter()
    vocab_dict = {name: id 
                  for id, name in enumerate(self.tokenizer.get_vocabulary())}

    for tokens in tqdm.tqdm(ds):
      counts.update(tokens.numpy().flatten())

    counts_arr = np.zeros(shape=(self.tokenizer.vocabulary_size(),))
    counts_arr[np.array(list(counts.keys()), dtype=np.int32)] = list(counts.values())

    counts_arr = counts_arr[:]
    for token in self.banned_tokens:
      counts_arr[vocab_dict[token]] = 0

    total = counts_arr.sum()
    p = counts_arr/total
    p[counts_arr==0] = 1.0
    log_p = np.log(p)  # log(1) == 0

    entropy = -(log_p*p).sum()

    print()
    print(f"Uniform entropy: {np.log(self.tokenizer.vocabulary_size()):0.2f}")
    print(f"Marginal entropy: {entropy:0.2f}")

    self.bias = log_p
    self.bias[counts_arr==0] = -1e9

  def call(self, x):
    x = self.dense(x)
    # TODO(b/250038731): Fix this.
    # An Add layer doesn't work because of the different shapes.
    # This clears the mask, that's okay because it prevents keras from rescaling
    # the losses.
    return x + self.bias

# %% [markdown]
# The smart initialization will significantly reduce the initial loss:

# %%
output_layer = TokenOutput(tokenizer, banned_tokens=('', '[UNK]', '[START]'))
# This might run a little faster if the dataset didn't also have to load the image data.
output_layer.adapt(new_train_dataset_raw.map(lambda inputs, labels: labels))
# Out:
# 938it [01:06, 14.01it/s]
# Uniform entropy: 8.52
# Marginal entropy: 5.29

# %%
class Captioner(tf.keras.Model):
  @classmethod
  def add_method(cls, fun):
    setattr(cls, fun.__name__, fun)
    return fun

  def __init__(self, tokenizer, feature_extractor, output_layer, num_layers=1,
               units=256, max_length=50, num_heads=1, dropout_rate=0.1):
    super().__init__()
    self.feature_extractor = feature_extractor
    self.tokenizer = tokenizer
    self.word_to_index = tf.keras.layers.StringLookup(
        mask_token="",
        vocabulary=tokenizer.get_vocabulary())
    self.index_to_word = tf.keras.layers.StringLookup(
        mask_token="",
        vocabulary=tokenizer.get_vocabulary(),
        invert=True) 

    self.seq_embedding = SeqEmbedding(
        vocab_size=tokenizer.vocabulary_size(),
        depth=units,
        max_length=max_length)

    self.decoder_layers = [
        DecoderLayer(units, num_heads=num_heads, dropout_rate=dropout_rate)
        for n in range(num_layers)]

    self.output_layer = output_layer

# %% [markdown]
# ### Build the model

# %% [markdown]
# To build the model, you need to combine several parts:
#
# 1. The image `feature_extractor` and the text `tokenizer` and.
# 1. The `seq_embedding` layer, to convert batches of token-IDs to
#    vectors `(batch, sequence, channels)`.
# 3. The stack of `DecoderLayers` layers that will process the text and image data.
# 4. The `output_layer` which returns a pointwise prediction of what the next word should be.

# %% [markdown]
# When you call the model, for training, it receives an `image, txt` pair. To make this function more usable, be flexible about the input:
#
# * If the image has 3 channels run it through the feature_extractor. Otherwise assume that it has been already. Similarly
# * If the text has dtype `tf.string` run it through the tokenizer.
#
# After that running the model is only a few steps:
#
# 1. Flatten the extracted image features, so they can be input to the decoder layers.
# 2. Look up the token embeddings.
# 3. Run the stack of `DecoderLayer`s, on the image features and text embeddings.
# 4. Run the output layer to predict the next token at each position.

# %% [markdown]
# # ================================================

# %% [markdown]
# # Continuing post Model starting here

# %%
# Decorate the method as a Captioner class method
@Captioner.add_method
def call(self, inputs):
    image, text = inputs

    # Apply the feature extractor to RGB images
    if image.shape[-1] == 3:
        image = self.feature_extractor(image)

    # Flatten the feature map
    image = einops.rearrange(image, 'b h w c -> b (h w) c')

    # Tokenize the text if it's a string input
    if text.dtype == tf.string:
        text = tokenizer(text)

    # Embed the sequence
    text = self.seq_embedding(text)

    # Pass the image through each decoder layer
    for decoder_layer in self.decoder_layers:
        text = decoder_layer(inputs=(image, text))

    # Apply the output layer
    text = self.output_layer(text)

    return text

# %%
#CHANGE: change here for units dropout num_layers, num_heads
model = Captioner(tokenizer, feature_extractor=mobilenet, output_layer=output_layer,
                  units=512, dropout_rate=0.3, num_layers=2, num_heads=2)

# %%
# before training save the weights & reload if you run a new experiment
model.save_weights('model.init')

# %% [markdown]
# ### Generate captions
#
# While training, generate captions for a test image to see how the training is progressing -

# %%
image = imageLoadResize(pic)

# %%
@Captioner.add_method
def simple_generator(self, image, temperature=1):
  # Initialize the list of output tokens with a `[START]` token.
  initial = self.word_to_index([['[START]']])
  #Extract the `img_features`
  img_features = self.feature_extractor(image[tf.newaxis, ...])

  tokens = initial
  for n in range(50):
    # Pass `img_features` and `tokens` into the model. It returns a list of logits.
    preds = self((img_features, tokens)).numpy()
    preds = preds[:,-1, :]
    # Choose the next token based on those logits.  
    if temperature==0:
        next = tf.argmax(preds, axis=-1)[:, tf.newaxis]
    else:
        next = tf.random.categorical(preds/temperature, num_samples=1)
    # Add it to the list of tokens, and continue the loop.
    tokens = tf.concat([tokens, next], axis=1)
    
    #If it generates an `'[END]'` token, break out of the loop.
    if next[0] == self.word_to_index('[END]'):
      break
  words = index_to_word(tokens[0, 1:-1])
  result = tf.strings.reduce_join(words, axis=-1, separator=' ')
  return result.numpy().decode()

# %% [markdown]
# Captions from untrained Model

# %%
pic
# Out:
# './archive/Flickr8k_Dataset/2513260012_03d33305cf.jpg'

# %%
labelcaption=label[0].decode('utf-8')

# %%
for t in (0.0, 0.5, 1.0):
  result = model.simple_generator(image, temperature=t)
  print(result)
# Out:
# a a a
# a a a a
# off for standing wall shirt china woods red skating each ball pink a diver

# %%
result
# Out:
# 'off for standing wall shirt china woods red skating each ball pink a diver'

# %%
# pre trainining Bleu
from nltk.translate.bleu_score import sentence_bleu

score = sentence_bleu(labelcaption, result)
print(f"BELU score: {score*100}")
# Out:
# BELU score: 1.2794358628081968e-229
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %% [markdown]
# # Completed

# %% [markdown]
# The temperature parameter allows you to interpolate between 3 modes:
#
# 1. Greedy decoding (`temperature=0.0`) - Chooses the most likely next token at each step.
# 2. Random sampling according to the logits (`temperature=1.0`).
# 3. Uniform random sampling (`temperature >> 1.0`).
#
# Since the model is untrained, and it used the frequency-based initialization, the "greedy" output (first) usually only contains the most common tokens: `['a', '.', '[END]']`.

# %% [markdown]
# ## Train

# %% [markdown]
# To train the model you'll need several additional components:
#
# - The Loss and metrics
# - The Optimizer
# - Optional Callbacks

# %% [markdown]
# ### Losses and metrics

# %% [markdown]
# Here's an implementation of a masked loss and accuracy:
#
# When calculating the mask for the loss, note the `loss < 1e8`. This term discards the artificial, impossibly high losses for the `banned_tokens`.

# %%
def masked_loss(labels, preds):  
  loss = tf.nn.sparse_softmax_cross_entropy_with_logits(labels, preds)

  mask = (labels != 0) & (loss < 1e8) 
  mask = tf.cast(mask, loss.dtype)

  loss = loss*mask
  loss = tf.reduce_sum(loss)/tf.reduce_sum(mask)
  return loss

def masked_acc(labels, preds):
  mask = tf.cast(labels!=0, tf.float32)
  preds = tf.argmax(preds, axis=-1)
  labels = tf.cast(labels, tf.int64)
  match = tf.cast(preds == labels, mask.dtype)
  acc = tf.reduce_sum(match*mask)/tf.reduce_sum(mask)
  return acc

# %% [markdown]
# ### Callbacks

# %% [markdown]
# For feedback during training setup a `keras.callbacks.Callback` to generate some captions for the surfer image at the end of each epoch.

# %%
x=plt.imread(pic)
plt.imshow(x)

# %%
class GenerateText(tf.keras.callbacks.Callback):
  def __init__(self):
    self.image = imageLoadResize(pic)

  def on_epoch_end(self, epochs=None, logs=None):
    print()
    print()
    for t in (0.0, 0.5, 1.0):
      result = self.model.simple_generator(self.image, temperature=t)
      print(result)
    print()

# %% [markdown]
# It generates three output strings, like the earlier example, like before the first is "greedy", choosing the argmax of the logits at each step.

# %%
g = GenerateText()
g.model = model
g.on_epoch_end(0)
# Out:
# a a a
# on are
# her hair the

# %% [markdown]
# Also use `callbacks.EarlyStopping` to terminate training when the model starts to overfit.

# %%
callbacks = [
    GenerateText(),
    tf.keras.callbacks.EarlyStopping(
        patience=15, restore_best_weights=True)]

# %% [markdown]
# ### Train

# %% [markdown]
# Configure and execute the training.

# %%
#CHANGE: change here for learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
           loss=masked_loss,
           metrics=[masked_acc])

# %% [markdown]
# For more frequent reporting, use the `Dataset.repeat()` method, and set the `steps_per_epoch` and `validation_steps` arguments to `Model.fit`.
#
# With this setup on `Flickr8k` a full pass over the dataset is 900+ batches, but below the reporting-epochs are 100 steps.

# %%
# start from model weight reload if you run it again

# %%
history = model.fit(
    new_train_dataset.repeat(),
    steps_per_epoch=100,
    validation_data=new_test_dataset.repeat(),
    validation_steps=20,
    epochs=100,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# 100/100 [==============================] - ETA: 0s - loss: 5.0271 - masked_acc: 0.1905
#
# a dog is dog in a dog is
# a dog is dog and pool
# a dog dry window in a brown female a hanging and dog of the his
#
# 100/100 [==============================] - 34s 206ms/step - loss: 5.0271 - masked_acc: 0.1905 - val_loss: 4.6946 - val_masked_acc: 0.2373
# Epoch 2/100
#  99/100 [============================>.] - ETA: 0s - loss: 4.6482 - masked_acc: 0.2486
#
# a dog is in the water
# a dog is playing in the the to the small brown black dog
# the boy in the tree from a blue air
#
# 100/100 [==============================] - 10s 102ms/step - loss: 4.6478 - masked_acc: 0.2490 - val_loss: 4.3924 - val_masked_acc: 0.2719
# Epoch 3/100
#  99/100 [============================>.] - ETA: 0s - loss: 4.4274 - masked_acc: 0.2701
#
# a dog is running in the water
# a dogs running in the snow
# a jacket dog over the with a and brown blue dog is player towards the red brown running dark looking to front next in the down front to a green firetruck
#
# 100/100 [==============================] - 9s 89ms/step - loss: 4.4261 - masked_acc: 0.2703 - val_loss: 4.2440 - val_masked_acc: 0.2732
# Epoch 4/100
#  99/100 [============================>.] - ETA: 0s - loss: 4.2616 - masked_acc: 0.2857
#
# a dog is running in the snow
# a brown dog is running on the white dog is running
# a black dog is jumping over as its cricket
#
# 100/100 [==============================] - 9s 86ms/step - loss: 4.2622 - masked_acc: 0.2855 - val_loss: 4.1641 - val_masked_acc: 0.2945
# Epoch 5/100
#  99/100 [============================>.] - ETA: 0s - loss: 4.1803 - masked_acc: 0.2973
#
# a brown dog is running in the snow
# a white dog is running in the of a black dog is running
# a small little black white dog in two around the boys for the water
#
# 100/100 [==============================] - 8s 80ms/step - loss: 4.1780 - masked_acc: 0.2975 - val_loss: 4.0762 - val_masked_acc: 0.3030
# Epoch 6/100
# 100/100 [==============================] - ETA: 0s - loss: 4.0875 - masked_acc: 0.3079
#
# a dog is running in the snow
# a dog is running in the a white dog
# dressed with skiers in its mouth racing
#
# 100/100 [==============================] - 8s 85ms/step - loss: 4.0875 - masked_acc: 0.3079 - val_loss: 3.9616 - val_masked_acc: 0.3175
# Epoch 7/100
# 100/100 [==============================] - ETA: 0s - loss: 3.9761 - masked_acc: 0.3206
#
# a dog is running on the snow
# a black dog running in the snow
# two dog and railings as a while looking down the red and each ball
#
# 100/100 [==============================] - 10s 96ms/step - loss: 3.9761 - masked_acc: 0.3206 - val_loss: 3.8704 - val_masked_acc: 0.3219
# Epoch 8/100
#  99/100 [============================>.] - ETA: 0s - loss: 3.9163 - masked_acc: 0.3215
#
# a dog is running through the snow
# a black dog is running through the snow
# a brown dog is running into a hiker is jumping on green road
#
# 100/100 [==============================] - 7s 66ms/step - loss: 3.9168 - masked_acc: 0.3215 - val_loss: 3.7423 - val_masked_acc: 0.3249
# Epoch 9/100
# 100/100 [==============================] - ETA: 0s - loss: 3.8700 - masked_acc: 0.3256
#
# a dog is running through the snow
# a black dog is running through the snow
# a black brown dog jumping in the snow
#
# 100/100 [==============================] - 8s 82ms/step - loss: 3.8700 - masked_acc: 0.3256 - val_loss: 3.7118 - val_masked_acc: 0.3297
# Epoch 10/100
#  99/100 [============================>.] - ETA: 0s - loss: 3.7445 - masked_acc: 0.3394
#
# a dog is running through the snow
# two black dog running on a a beach
# two white and dogs black and two dogs street
#
# 100/100 [==============================] - 7s 68ms/step - loss: 3.7400 - masked_acc: 0.3396 - val_loss: 3.6340 - val_masked_acc: 0.3374
# Epoch 11/100
# 100/100 [==============================] - ETA: 0s - loss: 3.6680 - masked_acc: 0.3451
#
# a dog is running through the snow
# a dog jumps over a large field
# a dogs running through the woods
#
# 100/100 [==============================] - 8s 78ms/step - loss: 3.6680 - masked_acc: 0.3451 - val_loss: 3.5812 - val_masked_acc: 0.3425
# Epoch 12/100
#  99/100 [============================>.] - ETA: 0s - loss: 3.6818 - masked_acc: 0.3417
#
# a black dog is running through the snow
# a black dog is running through the snow
# a young girl kicks the beach
#
# 100/100 [==============================] - 7s 69ms/step - loss: 3.6800 - masked_acc: 0.3419 - val_loss: 3.5295 - val_masked_acc: 0.3460
# Epoch 13/100
# 100/100 [==============================] - ETA: 0s - loss: 3.6267 - masked_acc: 0.3443
#
# a dog is running through the snow
# a dog runs through the snow
# a dogs surfing
#
# 100/100 [==============================] - 8s 76ms/step - loss: 3.6267 - masked_acc: 0.3443 - val_loss: 3.5847 - val_masked_acc: 0.3322
# Epoch 14/100
#  99/100 [============================>.] - ETA: 0s - loss: 3.5950 - masked_acc: 0.3466
#
# a dog is running through the snow
# a brown dog is running through the grass
# two brown dog dogs are river on the playground
#
# 100/100 [==============================] - 6s 64ms/step - loss: 3.5932 - masked_acc: 0.3468 - val_loss: 3.5667 - val_masked_acc: 0.3382
# Epoch 15/100
# 100/100 [==============================] - ETA: 0s - loss: 3.5419 - masked_acc: 0.3507
#
# a dog is running through the snow
# a dogs running through the woods
# two dogs jumping into the snow
#
# 100/100 [==============================] - 8s 84ms/step - loss: 3.5419 - masked_acc: 0.3507 - val_loss: 3.5100 - val_masked_acc: 0.3528
# Epoch 16/100
#  99/100 [============================>.] - ETA: 0s - loss: 3.5487 - masked_acc: 0.3453
#
# a dog running through the snow
# a brown dog runs in the snow
# the dog swimming hill with mud making the ocean
#
# 100/100 [==============================] - 7s 67ms/step - loss: 3.5474 - masked_acc: 0.3453 - val_loss: 3.4912 - val_masked_acc: 0.3499
# Epoch 17/100
# 100/100 [==============================] - ETA: 0s - loss: 3.5075 - masked_acc: 0.3525
#
# a dog running through the snow
# a dog runs through the snow
# a black dog running through a small fenced small grassy field
#
# 100/100 [==============================] - 8s 80ms/step - loss: 3.5075 - masked_acc: 0.3525 - val_loss: 3.4506 - val_masked_acc: 0.3517
# Epoch 18/100
#  99/100 [============================>.] - ETA: 0s - loss: 3.4773 - masked_acc: 0.3584
#
# a dog running through the snow
# two dogs playing with a stick in its mouth
# the striped dog is running down a large wave
#
# 100/100 [==============================] - 7s 71ms/step - loss: 3.4777 - masked_acc: 0.3582 - val_loss: 3.4257 - val_masked_acc: 0.3537
# Epoch 19/100
# 100/100 [==============================] - ETA: 0s - loss: 3.4501 - masked_acc: 0.3622
#
# a dog running through the snow
# a dog is running across the background
# three white dogs run through the water
#
# 100/100 [==============================] - 7s 73ms/step - loss: 3.4501 - masked_acc: 0.3622 - val_loss: 3.3768 - val_masked_acc: 0.3470
# Epoch 20/100
#  99/100 [============================>.] - ETA: 0s - loss: 3.3238 - masked_acc: 0.3666
#
# a dog is running through the snow
# a dog is running in the snow
# a small dog runs across the snow
#
# 100/100 [==============================] - 7s 66ms/step - loss: 3.3236 - masked_acc: 0.3667 - val_loss: 3.3775 - val_masked_acc: 0.3609
# Epoch 21/100
#  99/100 [============================>.] - ETA: 0s - loss: 3.3201 - masked_acc: 0.3708
#
# a black dog is running through the snow
# a black and white dog runs through the snow
# a dog jumps into the water
#
# 100/100 [==============================] - 6s 65ms/step - loss: 3.3229 - masked_acc: 0.3704 - val_loss: 3.3749 - val_masked_acc: 0.3558
# Epoch 22/100
#  99/100 [============================>.] - ETA: 0s - loss: 3.3190 - masked_acc: 0.3708
#
# a brown dog is running through the snow
# two dogs run through the snow
# a large grey dog running in the water
#
# 100/100 [==============================] - 8s 76ms/step - loss: 3.3187 - masked_acc: 0.3710 - val_loss: 3.3109 - val_masked_acc: 0.3624
# Epoch 23/100
#  99/100 [============================>.] - ETA: 0s - loss: 3.3205 - masked_acc: 0.3706
#
# a black dog is running through the snow
# a brown dog puppy running through the snow
# two its dogs play together in the side of the snow
#
# 100/100 [==============================] - 7s 67ms/step - loss: 3.3190 - masked_acc: 0.3708 - val_loss: 3.2184 - val_masked_acc: 0.3696
# Epoch 24/100
# 100/100 [==============================] - ETA: 0s - loss: 3.2504 - masked_acc: 0.3711
#
# a brown dog is running through the snow
# a brown dog is running through the snow
# two dogs running on the grass
#
# 100/100 [==============================] - 7s 71ms/step - loss: 3.2504 - masked_acc: 0.3711 - val_loss: 3.2668 - val_masked_acc: 0.3612
# Epoch 25/100
#  99/100 [============================>.] - ETA: 0s - loss: 3.2774 - masked_acc: 0.3717
#
# a black dog is running through the snow
# a black dog is running through the snow
# two dogs playing in the air
#
# 100/100 [==============================] - 6s 63ms/step - loss: 3.2789 - masked_acc: 0.3714 - val_loss: 3.2064 - val_masked_acc: 0.3747
# Epoch 26/100
# 100/100 [==============================] - ETA: 0s - loss: 3.2413 - masked_acc: 0.3728
#
# a dog running through the snow
# a dog running through the snow
# kids playing young running
#
# 100/100 [==============================] - 8s 82ms/step - loss: 3.2413 - masked_acc: 0.3728 - val_loss: 3.2474 - val_masked_acc: 0.3621
# Epoch 27/100
#  99/100 [============================>.] - ETA: 0s - loss: 3.2247 - masked_acc: 0.3784
#
# a dog running through the snow
# a black dog running through the snow
# a golden greyhound dog runs along a beach with other on their side of some water
#
# 100/100 [==============================] - 7s 66ms/step - loss: 3.2286 - masked_acc: 0.3779 - val_loss: 3.2964 - val_masked_acc: 0.3566
# Epoch 28/100
# 100/100 [==============================] - ETA: 0s - loss: 3.2172 - masked_acc: 0.3767
#
# a dog running through the snow
# a dog runs through the snow
# brown dog jumps to catch a blue toy and groom ball by down it
#
# 100/100 [==============================] - 8s 75ms/step - loss: 3.2172 - masked_acc: 0.3767 - val_loss: 3.2699 - val_masked_acc: 0.3652
# Epoch 29/100
#  99/100 [============================>.] - ETA: 0s - loss: 3.1184 - masked_acc: 0.3843
#
# two dogs play in the snow
# two big dogs are running through the snow
# the a white dog holds a brown black dog
#
# 100/100 [==============================] - 7s 65ms/step - loss: 3.1152 - masked_acc: 0.3849 - val_loss: 3.2112 - val_masked_acc: 0.3775
# Epoch 30/100
# 100/100 [==============================] - ETA: 0s - loss: 3.0939 - masked_acc: 0.3901
#
# a dog is running through the snow
# a dog is running through the snow
# the dogs play outside
#
# 100/100 [==============================] - 7s 71ms/step - loss: 3.0939 - masked_acc: 0.3901 - val_loss: 3.2294 - val_masked_acc: 0.3580
# Epoch 31/100
# 100/100 [==============================] - ETA: 0s - loss: 3.0993 - masked_acc: 0.3839
#
# a dog is running through the snow
# two dogs run down a snow
# the black dog is jumping in the snow
#
# 100/100 [==============================] - 6s 59ms/step - loss: 3.0993 - masked_acc: 0.3839 - val_loss: 3.2250 - val_masked_acc: 0.3617
# Epoch 32/100
# 100/100 [==============================] - ETA: 0s - loss: 3.0887 - masked_acc: 0.3892
#
# a dog is running through the snow
# a black dog is running through the snow
# a dog is walking through the snow
#
# 100/100 [==============================] - 7s 74ms/step - loss: 3.0887 - masked_acc: 0.3892 - val_loss: 3.1199 - val_masked_acc: 0.3805
# Epoch 33/100
# 100/100 [==============================] - ETA: 0s - loss: 3.0761 - masked_acc: 0.3878
#
# a dog runs through the snow
# two dogs are fighting in the snow
# black dog is running through the sand
#
# 100/100 [==============================] - 6s 59ms/step - loss: 3.0761 - masked_acc: 0.3878 - val_loss: 3.2088 - val_masked_acc: 0.3616
# Epoch 34/100
# 100/100 [==============================] - ETA: 0s - loss: 3.0553 - masked_acc: 0.3918
#
# two dogs are running through the snow
# two dogs play in the snow
# two dogs behind him on a field
#
# 100/100 [==============================] - 7s 72ms/step - loss: 3.0553 - masked_acc: 0.3918 - val_loss: 3.1110 - val_masked_acc: 0.3821
# Epoch 35/100
# 100/100 [==============================] - ETA: 0s - loss: 3.0620 - masked_acc: 0.3894
#
# two dogs play in the snow
# a dog running through the snow
# three dogs fighting over each other on a fence
#
# 100/100 [==============================] - 7s 71ms/step - loss: 3.0620 - masked_acc: 0.3894 - val_loss: 3.1452 - val_masked_acc: 0.3728
# Epoch 36/100
# 100/100 [==============================] - ETA: 0s - loss: 3.0434 - masked_acc: 0.3912
#
# a dog is running through the snow
# a dog is running through the snow
# a and white dog is running in the snow
#
# 100/100 [==============================] - 7s 72ms/step - loss: 3.0434 - masked_acc: 0.3912 - val_loss: 3.1113 - val_masked_acc: 0.3785
# Epoch 37/100
#  99/100 [============================>.] - ETA: 0s - loss: 3.0317 - masked_acc: 0.3917
#
# two dogs play in the snow
# two dogs playing in the snow
# two brown dogs are playing on in the snow
#
# 100/100 [==============================] - 6s 64ms/step - loss: 3.0339 - masked_acc: 0.3916 - val_loss: 3.1119 - val_masked_acc: 0.3745
# Epoch 38/100
# 100/100 [==============================] - ETA: 0s - loss: 2.9928 - masked_acc: 0.3981
#
# two dogs playing in the snow
# a dog with a black dog is running through the sand
# a brown dog is running towards the ball on the beach
#
# 100/100 [==============================] - 8s 79ms/step - loss: 2.9928 - masked_acc: 0.3981 - val_loss: 3.0940 - val_masked_acc: 0.3726
# Epoch 39/100
#  99/100 [============================>.] - ETA: 0s - loss: 2.8983 - masked_acc: 0.4067
#
# two dogs are running through the snow
# two large brown dogs are playing with a ball in the snow
# a skinny small dog is back on some wood where a large other
#
# 100/100 [==============================] - 7s 68ms/step - loss: 2.9006 - masked_acc: 0.4065 - val_loss: 3.0672 - val_masked_acc: 0.3866
# Epoch 40/100
# 100/100 [==============================] - ETA: 0s - loss: 2.9436 - masked_acc: 0.4032
#
# two dogs running through the snow
# two dogs running through the snow
# two muzzled dogs playing with not with out it
#
# 100/100 [==============================] - 7s 75ms/step - loss: 2.9436 - masked_acc: 0.4032 - val_loss: 3.0982 - val_masked_acc: 0.3689
# Epoch 41/100
# 100/100 [==============================] - ETA: 0s - loss: 2.9348 - masked_acc: 0.4020
#
# a dog running through the snow
# two dogs playing with a ball in the snow
# two black dogs in the air at a beach
#
# 100/100 [==============================] - 7s 69ms/step - loss: 2.9348 - masked_acc: 0.4020 - val_loss: 3.0642 - val_masked_acc: 0.3756
# Epoch 42/100
# 100/100 [==============================] - ETA: 0s - loss: 2.9065 - masked_acc: 0.4042
#
# two dogs play in the snow
# two dogs are playing on the snow
# dog playing on a water
#
# 100/100 [==============================] - 8s 78ms/step - loss: 2.9065 - masked_acc: 0.4042 - val_loss: 3.1008 - val_masked_acc: 0.3801
# Epoch 43/100
#  99/100 [============================>.] - ETA: 0s - loss: 2.9034 - masked_acc: 0.4059
#
# a brown dog is running through the snow
# a dog is running through a grassy field
# two brown toy dogs are running on the ground
#
# 100/100 [==============================] - 7s 67ms/step - loss: 2.9014 - masked_acc: 0.4063 - val_loss: 3.1227 - val_masked_acc: 0.3659
# Epoch 44/100
# 100/100 [==============================] - ETA: 0s - loss: 2.8891 - masked_acc: 0.4041
#
# two dogs run through the snow
# two dogs play in the snow
# three dogs walk through a dry grass
#
# 100/100 [==============================] - 7s 74ms/step - loss: 2.8891 - masked_acc: 0.4041 - val_loss: 3.0834 - val_masked_acc: 0.3770
# Epoch 45/100
# 100/100 [==============================] - ETA: 0s - loss: 2.8934 - masked_acc: 0.4045
#
# two dogs play in the snow
# a dog running through the snow
# three dogs are running down in the snow
#
# 100/100 [==============================] - 7s 75ms/step - loss: 2.8934 - masked_acc: 0.4045 - val_loss: 3.0172 - val_masked_acc: 0.3772
# Epoch 46/100
# 100/100 [==============================] - ETA: 0s - loss: 2.9037 - masked_acc: 0.4045
#
# two dogs play in the snow
# two dogs playing in the snow
# three dogs play in the snow
#
# 100/100 [==============================] - 8s 77ms/step - loss: 2.9037 - masked_acc: 0.4045 - val_loss: 2.9875 - val_masked_acc: 0.3800
# Epoch 47/100
# 100/100 [==============================] - ETA: 0s - loss: 2.8759 - masked_acc: 0.4033
#
# a brown dog is running through the snow
# a dog running through the snow
# two dogs play making a rocky out before the same dog
#
# 100/100 [==============================] - 7s 72ms/step - loss: 2.8759 - masked_acc: 0.4033 - val_loss: 2.9892 - val_masked_acc: 0.3884
# Epoch 48/100
#  99/100 [============================>.] - ETA: 0s - loss: 2.7533 - masked_acc: 0.4181
#
# two dogs play in the snow
# a dog with its mouth is jumping into the air
# two dogs play in a camera
#
# 100/100 [==============================] - 7s 69ms/step - loss: 2.7520 - masked_acc: 0.4189 - val_loss: 3.0489 - val_masked_acc: 0.3734
# Epoch 49/100
# 100/100 [==============================] - ETA: 0s - loss: 2.7637 - masked_acc: 0.4203
#
# two dogs play in the snow
# two dogs play in the snow
# a the black dog runs towards the snow
#
# 100/100 [==============================] - 6s 59ms/step - loss: 2.7637 - masked_acc: 0.4203 - val_loss: 3.0219 - val_masked_acc: 0.3819
# Epoch 50/100
#  99/100 [============================>.] - ETA: 0s - loss: 2.7616 - masked_acc: 0.4177
#
# two dogs play in the snow
# three dogs play in the snow
# two yellow dogs are running together
#
# 100/100 [==============================] - 7s 72ms/step - loss: 2.7612 - masked_acc: 0.4179 - val_loss: 2.9944 - val_masked_acc: 0.3833
# Epoch 51/100
# 100/100 [==============================] - ETA: 0s - loss: 2.7973 - masked_acc: 0.4141
#
# two dogs run through the snow
# two dogs run through the snow
# two brown dogs are playing with a ball
#
# 100/100 [==============================] - 7s 66ms/step - loss: 2.7973 - masked_acc: 0.4141 - val_loss: 2.9999 - val_masked_acc: 0.3818
# Epoch 52/100
# 100/100 [==============================] - ETA: 0s - loss: 2.7955 - masked_acc: 0.4182
#
# a black dog is running through the snow
# two dogs running through the snow
# two dogs running down a snowy hill
#
# 100/100 [==============================] - 7s 73ms/step - loss: 2.7955 - masked_acc: 0.4182 - val_loss: 3.0244 - val_masked_acc: 0.3754
# Epoch 53/100
#  99/100 [============================>.] - ETA: 0s - loss: 2.7729 - masked_acc: 0.4196
#
# two dogs play in the snow
# a black dog runs through the snow
# the dogs is leaping up running across the snow
#
# 100/100 [==============================] - 6s 60ms/step - loss: 2.7739 - masked_acc: 0.4194 - val_loss: 3.0225 - val_masked_acc: 0.3762
# Epoch 54/100
# 100/100 [==============================] - ETA: 0s - loss: 2.7479 - masked_acc: 0.4185
#
# a dog is running through the snow
# a dog is running across the snow
# the dog is running with something in the snow covered leaves
#
# 100/100 [==============================] - 8s 78ms/step - loss: 2.7479 - masked_acc: 0.4185 - val_loss: 3.0052 - val_masked_acc: 0.3881
# Epoch 55/100
# 100/100 [==============================] - ETA: 0s - loss: 2.7724 - masked_acc: 0.4186
#
# a dog is running through the snow
# two dogs running through the snow
# a black dog is running into the water
#
# 100/100 [==============================] - 6s 62ms/step - loss: 2.7724 - masked_acc: 0.4186 - val_loss: 2.9452 - val_masked_acc: 0.3867
# Epoch 56/100
# 100/100 [==============================] - ETA: 0s - loss: 2.7892 - masked_acc: 0.4180
#
# two dogs play in the snow
# two dogs are playing in the snow
# terrier motorcyclist jumping over a wall
#
# 100/100 [==============================] - 8s 75ms/step - loss: 2.7892 - masked_acc: 0.4180 - val_loss: 2.9983 - val_masked_acc: 0.3819
# Epoch 57/100
# 100/100 [==============================] - ETA: 0s - loss: 2.6687 - masked_acc: 0.4293
#
# two dogs playing in the snow
# two dogs running in the snow
# two dogs playing tug of a body of splashed
#
# 100/100 [==============================] - 6s 62ms/step - loss: 2.6687 - masked_acc: 0.4293 - val_loss: 2.9772 - val_masked_acc: 0.3755
# Epoch 58/100
# 100/100 [==============================] - ETA: 0s - loss: 2.6276 - masked_acc: 0.4368
#
# two dogs playing in the snow
# two dogs playing in the snow
# a big small black dog chases tan dog block of wood sign
#
# 100/100 [==============================] - 8s 81ms/step - loss: 2.6276 - masked_acc: 0.4368 - val_loss: 3.0216 - val_masked_acc: 0.3762
# Epoch 59/100
# 100/100 [==============================] - ETA: 0s - loss: 2.6589 - masked_acc: 0.4300
#
# two dogs play in the snow
# two dogs are running on a beach
# a black dog jumps out of the water are playing on the ground
#
# 100/100 [==============================] - 7s 68ms/step - loss: 2.6589 - masked_acc: 0.4300 - val_loss: 2.9686 - val_masked_acc: 0.3819
# Epoch 60/100
#  99/100 [============================>.] - ETA: 0s - loss: 2.6318 - masked_acc: 0.4327
#
# two dogs play in the snow
# a dog chasing a ball in the snow
# three spotted dogs play together on the snow with something in its mouth
#
# 100/100 [==============================] - 8s 78ms/step - loss: 2.6322 - masked_acc: 0.4326 - val_loss: 3.0130 - val_masked_acc: 0.3751
# Epoch 61/100
#  99/100 [============================>.] - ETA: 0s - loss: 2.6913 - masked_acc: 0.4242
#
# a black dog is running through the snow
# a black dog is running through the snow
# three dogs playing in the snow
#
# 100/100 [==============================] - 7s 72ms/step - loss: 2.6914 - masked_acc: 0.4245 - val_loss: 2.9825 - val_masked_acc: 0.3860
# Epoch 62/100
# 100/100 [==============================] - ETA: 0s - loss: 2.6563 - masked_acc: 0.4301
#
# two dogs play in the snow
# two dogs running on the snow
# a small dog running downhill
#
# 100/100 [==============================] - 7s 68ms/step - loss: 2.6563 - masked_acc: 0.4301 - val_loss: 2.9991 - val_masked_acc: 0.3835
# Epoch 63/100
# 100/100 [==============================] - ETA: 0s - loss: 2.6665 - masked_acc: 0.4266
#
# two dogs play in the snow
# three dogs run along the beach
# a spotted dog is catching a tennis ball in the snow
#
# 100/100 [==============================] - 7s 66ms/step - loss: 2.6665 - masked_acc: 0.4266 - val_loss: 2.9365 - val_masked_acc: 0.3845
# Epoch 64/100
# 100/100 [==============================] - ETA: 0s - loss: 2.6380 - masked_acc: 0.4288
#
# two dogs play in the snow
# two dogs fight over the snow
# two dogs play in an amusement park
#
# 100/100 [==============================] - 7s 71ms/step - loss: 2.6380 - masked_acc: 0.4288 - val_loss: 2.9950 - val_masked_acc: 0.3804
# Epoch 65/100
# 100/100 [==============================] - ETA: 0s - loss: 2.6760 - masked_acc: 0.4268
#
# two dogs are playing in the snow
# two dogs are playing in the snow
# two dog playing in a laptop attempt to catch an orange object
#
# 100/100 [==============================] - 9s 90ms/step - loss: 2.6760 - masked_acc: 0.4268 - val_loss: 3.0562 - val_masked_acc: 0.3783
# Epoch 66/100
# 100/100 [==============================] - ETA: 0s - loss: 2.6068 - masked_acc: 0.4316
#
# two dogs play in the snow
# three dogs are running on a snowy field
# black dog has a body of water
#
# 100/100 [==============================] - 6s 61ms/step - loss: 2.6068 - masked_acc: 0.4316 - val_loss: 2.9472 - val_masked_acc: 0.3821
# Epoch 67/100
#  99/100 [============================>.] - ETA: 0s - loss: 2.5236 - masked_acc: 0.4463
#
# two dogs run through the snow
# a dog runs through the snow
# two dogs running with long ears in the white race
#
# 100/100 [==============================] - 6s 64ms/step - loss: 2.5255 - masked_acc: 0.4459 - val_loss: 2.9761 - val_masked_acc: 0.3855
# Epoch 68/100
#  99/100 [============================>.] - ETA: 0s - loss: 2.5167 - masked_acc: 0.4471
#
# two dogs running on the snow
# two dogs running on the grass
# two dogs tied to his furry dogs fight over a tennis ball in his mouth
#
# 100/100 [==============================] - 7s 67ms/step - loss: 2.5178 - masked_acc: 0.4469 - val_loss: 3.0026 - val_masked_acc: 0.3862
# Epoch 69/100
#  99/100 [============================>.] - ETA: 0s - loss: 2.5448 - masked_acc: 0.4441
#
# a black dog and a black dog are running through the snow
# a black dog and a brown dog is running down
# a wet black puppy two dogs run through the snow
#
# 100/100 [==============================] - 7s 73ms/step - loss: 2.5470 - masked_acc: 0.4436 - val_loss: 3.0081 - val_masked_acc: 0.3895
# Epoch 70/100
#  99/100 [============================>.] - ETA: 0s - loss: 2.5469 - masked_acc: 0.4410
#
# two dogs playing in the snow
# two dogs playing on the snow
# two little white dogs play in the sand with a leafy tail of large surfer behind
#
# 100/100 [==============================] - 7s 67ms/step - loss: 2.5491 - masked_acc: 0.4407 - val_loss: 2.9374 - val_masked_acc: 0.3862
# Epoch 71/100
#  99/100 [============================>.] - ETA: 0s - loss: 2.5365 - masked_acc: 0.4420
#
# two dogs play in the snow
# two dogs play in the snow
# three dogs play on the small tan toy
#
# 100/100 [==============================] - 7s 71ms/step - loss: 2.5356 - masked_acc: 0.4418 - val_loss: 2.9489 - val_masked_acc: 0.3880
# Epoch 72/100
# 100/100 [==============================] - ETA: 0s - loss: 2.5911 - masked_acc: 0.4328
#
# two dogs play in the snow
# two dogs running through the snow
# two brown and white dogs fight over snow
#
# 100/100 [==============================] - 7s 68ms/step - loss: 2.5911 - masked_acc: 0.4328 - val_loss: 2.9310 - val_masked_acc: 0.3887
# Epoch 73/100
#  99/100 [============================>.] - ETA: 0s - loss: 2.5461 - masked_acc: 0.4404
#
# two dogs play in the snow
# a dog is running across the grass
# the black dog is running through a sandy area
#
# 100/100 [==============================] - 7s 73ms/step - loss: 2.5490 - masked_acc: 0.4403 - val_loss: 2.9485 - val_masked_acc: 0.3775
# Epoch 74/100
# 100/100 [==============================] - ETA: 0s - loss: 2.5522 - masked_acc: 0.4391
#
# two dogs play in the snow
# two dogs play in the snow
# two brown dogs play in the snow
#
# 100/100 [==============================] - 6s 59ms/step - loss: 2.5522 - masked_acc: 0.4391 - val_loss: 3.0149 - val_masked_acc: 0.3825
# Epoch 75/100
# 100/100 [==============================] - ETA: 0s - loss: 2.5570 - masked_acc: 0.4360
#
# a black dog and a black dog are running on the beach
# a dog is running along a beach
# a black dog is running through the snow
#
# 100/100 [==============================] - 8s 78ms/step - loss: 2.5570 - masked_acc: 0.4360 - val_loss: 2.9733 - val_masked_acc: 0.3791
# Epoch 76/100
# 100/100 [==============================] - ETA: 0s - loss: 2.4331 - masked_acc: 0.4562
#
# two dogs are running through the snow
# a brown dog chasing a ball in the snow
# two little dogs are running on the sand in the snow
#
# 100/100 [==============================] - 6s 65ms/step - loss: 2.4331 - masked_acc: 0.4562 - val_loss: 2.9633 - val_masked_acc: 0.3826
# Epoch 77/100
# 100/100 [==============================] - ETA: 0s - loss: 2.4500 - masked_acc: 0.4562
#
# two dogs play in the snow
# two dogs running along a snowy hill
# two brown dogs run down a snowy hill
#
# 100/100 [==============================] - 7s 74ms/step - loss: 2.4500 - masked_acc: 0.4562 - val_loss: 3.0471 - val_masked_acc: 0.3826
# Epoch 78/100
#  99/100 [============================>.] - ETA: 0s - loss: 2.4535 - masked_acc: 0.4503
#
# two dogs play in the snow
# two dogs running through the snow
# two brown dogs run through the woods after a white dog
#
# 100/100 [==============================] - 6s 60ms/step - loss: 2.4540 - masked_acc: 0.4503 - val_loss: 2.9257 - val_masked_acc: 0.3905
# Epoch 79/100
# 100/100 [==============================] - ETA: 0s - loss: 2.4481 - masked_acc: 0.4532
#
# two dogs running through the snow
# two dogs are running on snow
# two dogs play in the snow
#
# 100/100 [==============================] - 7s 70ms/step - loss: 2.4481 - masked_acc: 0.4532 - val_loss: 2.9278 - val_masked_acc: 0.3908
# Epoch 80/100
#  99/100 [============================>.] - ETA: 0s - loss: 2.4706 - masked_acc: 0.4491
#
# two dogs are running through the snow
# two dogs play in the snow
# a fluffy puppy running along a snow with binoculars in the background
#
# 100/100 [==============================] - 6s 61ms/step - loss: 2.4711 - masked_acc: 0.4490 - val_loss: 2.9026 - val_masked_acc: 0.3964
# Epoch 81/100
#  99/100 [============================>.] - ETA: 0s - loss: 2.4457 - masked_acc: 0.4525
#
# two dogs are playing in the snow
# two dogs are playing in the snow
# two dogs one black and white laying in the snowy field
#
# 100/100 [==============================] - 7s 70ms/step - loss: 2.4445 - masked_acc: 0.4529 - val_loss: 2.9857 - val_masked_acc: 0.3815
# Epoch 82/100
# 100/100 [==============================] - ETA: 0s - loss: 2.4528 - masked_acc: 0.4510
#
# two dogs play in the snow
# three dogs running on a snowy field
# two dogs run along some vehicles running around each other on snowcovered surface
#
# 100/100 [==============================] - 7s 69ms/step - loss: 2.4528 - masked_acc: 0.4510 - val_loss: 2.9349 - val_masked_acc: 0.3849
# Epoch 83/100
# 100/100 [==============================] - ETA: 0s - loss: 2.4458 - masked_acc: 0.4527
#
# two dogs play in the snow
# a black dog runs through the snow
# a tan dog leaps in its mouth open on a snowy yard
#
# 100/100 [==============================] - 8s 80ms/step - loss: 2.4458 - masked_acc: 0.4527 - val_loss: 2.9229 - val_masked_acc: 0.3915
# Epoch 84/100
#  99/100 [============================>.] - ETA: 0s - loss: 2.4762 - masked_acc: 0.4478
#
# two dogs play in the snow
# a dog and a brown dog are playing in the snow
# a brown dog is running through holding a tiger
#
# 100/100 [==============================] - 7s 70ms/step - loss: 2.4779 - masked_acc: 0.4475 - val_loss: 2.9863 - val_masked_acc: 0.3820
# Epoch 85/100
# 100/100 [==============================] - ETA: 0s - loss: 2.3952 - masked_acc: 0.4627
#
# two dogs play in the snow
# two dogs play in the snow
# a fluffy dog is biting the stick
#
# 100/100 [==============================] - 10s 100ms/step - loss: 2.3952 - masked_acc: 0.4627 - val_loss: 3.0111 - val_masked_acc: 0.3706
# Epoch 86/100
#  99/100 [============================>.] - ETA: 0s - loss: 2.3558 - masked_acc: 0.4632
#
# a dog chases a small black dog
# two dogs play on the beach
# a dog chews backpack on a slipper while playing with a christmas objects
#
# 100/100 [==============================] - 6s 63ms/step - loss: 2.3554 - masked_acc: 0.4632 - val_loss: 2.9332 - val_masked_acc: 0.3837
# Epoch 87/100
# 100/100 [==============================] - ETA: 0s - loss: 2.3569 - masked_acc: 0.4652
#
# two dogs run through the snow
# two dogs play together on a snowy field
# a at dog chasing a ball
#
# 100/100 [==============================] - 8s 78ms/step - loss: 2.3569 - masked_acc: 0.4652 - val_loss: 2.9907 - val_masked_acc: 0.3772
# Epoch 88/100
# 100/100 [==============================] - ETA: 0s - loss: 2.3521 - masked_acc: 0.4637
#
# two dogs play in the snow
# two dogs are playing in the snow
# two large dogs are playing tug of war with their toy
#
# 100/100 [==============================] - 7s 68ms/step - loss: 2.3521 - masked_acc: 0.4637 - val_loss: 2.9963 - val_masked_acc: 0.3821
# Epoch 89/100
#  99/100 [============================>.] - ETA: 0s - loss: 2.3643 - masked_acc: 0.4634
#
# two dogs play in the snow
# two dogs are running on the ground
# two dogs run together along a beach
#
# 100/100 [==============================] - 8s 77ms/step - loss: 2.3645 - masked_acc: 0.4635 - val_loss: 2.9731 - val_masked_acc: 0.3821
# Epoch 90/100
# 100/100 [==============================] - ETA: 0s - loss: 2.3862 - masked_acc: 0.4556
#
# two dogs play in the snow
# two dogs play in the snow
# two dogs are playing in a snowy grass
#
# 100/100 [==============================] - 6s 65ms/step - loss: 2.3862 - masked_acc: 0.4556 - val_loss: 2.9583 - val_masked_acc: 0.3868
# Epoch 91/100
#  99/100 [============================>.] - ETA: 0s - loss: 2.3918 - masked_acc: 0.4597
#
# two dogs play in the snow
# two dogs play in the snow
# two dogs running down at a sandy hill
#
# 100/100 [==============================] - 8s 79ms/step - loss: 2.3914 - masked_acc: 0.4598 - val_loss: 3.0004 - val_masked_acc: 0.3797
# Epoch 92/100
# 100/100 [==============================] - ETA: 0s - loss: 2.3861 - masked_acc: 0.4588
#
# two dogs play together
# two dogs are playing with a tennis ball in the snow
# two dogs play with a red ball in the snow
#
# 100/100 [==============================] - 6s 65ms/step - loss: 2.3861 - masked_acc: 0.4588 - val_loss: 2.9954 - val_masked_acc: 0.3839
# Epoch 93/100
# 100/100 [==============================] - ETA: 0s - loss: 2.3706 - masked_acc: 0.4617
#
# two dogs play in the snow
# two dogs play together on the beach
# two dogs play with a sprinkler
#
# 100/100 [==============================] - 7s 75ms/step - loss: 2.3706 - masked_acc: 0.4617 - val_loss: 2.9133 - val_masked_acc: 0.3886
# Epoch 94/100
# 100/100 [==============================] - ETA: 0s - loss: 2.3437 - masked_acc: 0.4641
#
# two dogs play in the snow
# two dogs running through the snow
# a gray dog is playing with a yellow toy
#
# 100/100 [==============================] - 6s 61ms/step - loss: 2.3437 - masked_acc: 0.4641 - val_loss: 2.9516 - val_masked_acc: 0.3857
# Epoch 95/100
# 100/100 [==============================] - ETA: 0s - loss: 2.2770 - masked_acc: 0.4732
#
# two dogs running in the snow
# two dogs running through the snow
# two black dogs run along the beach
#
# 100/100 [==============================] - 8s 79ms/step - loss: 2.2770 - masked_acc: 0.4732 - val_loss: 2.9770 - val_masked_acc: 0.3837

# %% [markdown]
# Plot the loss and accuracy over the training run:

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch #')
plt.ylabel('CE/token')
plt.legend()

# %%
plt.plot(history.history['masked_acc'], label='accuracy')
plt.plot(history.history['val_masked_acc'], label='val_accuracy')
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch #')
plt.ylabel('CE/token')
plt.legend()

# %% [markdown]
# ## Attention plots

# %% [markdown]
# Now, using the trained model,  run that `simple_generator` method on the image:

# %%
result = model.simple_generator(image, temperature=0.0)
result
# Out:
# 'two dogs are running through the snow'

# %%
label
# Out:
# array([b'A black dog is running after a white dog in the snow .',
#        b'Black dog chasing brown dog through snow',
#        b'Two dogs chase each other across the snowy ground .',
#        b'Two dogs play together in the snow .',
#        b'Two dogs running through a low lying body of water .'],
#       dtype=object)

# %%
from nltk.translate.bleu_score import corpus_bleu
def get_bleu_Score(pic,captions):
  image = imageLoadResize(pic)
  result = model.simple_generator(image, temperature=0.0)
  res = []
  labels = []
  for i in range(len(label)):
    res.append(result)
    labels.append(label[i].decode('utf-8').split(' '))
    score = corpus_bleu(labels, res)
    return score*100

def get_bleu_top_20(test_captions):
  scores = []
  for (pic, captions) in tqdm.tqdm(test_captions):
    # print(pic)
    scores.append(get_bleu_Score(pic, captions))
  sortedscores = sorted(scores)
  avg20 = sum(sortedscores[-20:])/20
  avg50 = sum(sortedscores[-50:])/50
  avg100 = sum(sortedscores[-100:])/100
  avg200 = sum(sortedscores[-200:])/200
  avg400 = sum(sortedscores[-400:])/400
  return (avg20, avg50, avg100, avg200, avg400)

# %%
get_bleu_top_20(test_captions)
# Out:
# 100%|██████████| 1000/1000 [13:48<00:00,  1.21it/s]
# (32.13307850455098, 29.754979876618357, 27.13864061555582)

# %%
# post trainining Bleu
from nltk.translate.bleu_score import sentence_bleu
labelcaption = label[3].decode('utf-8')
print(labelcaption)
print(result)
score = sentence_bleu(labelcaption, result)
# print(f"BELU score: {score*100}")

from nltk.translate.bleu_score import corpus_bleu
res = []
labels = []
for i in range(len(label)):
  res.append(result)
  labels.append(label[i].decode('utf-8').split(' '))

# print(res)
# print(labels)
score = corpus_bleu(labels, res)
print(f"BELU Corpus: {score*100}")

# sentence_bleu([reference1, reference2, reference3], hypothesis2,
#     ...     smoothing_function=chencherry.method1)

score = sentence_bleu(labels, result.split(' '))
# print(f"BELU Corpus new: {score*100}")
# Out:
# Two dogs play together in the snow .
# two dogs are running through the snow
# BELU Corpus: 25.74471263969855

# %%
print(res)
# Out:
# ['two dogs are running through the snow', 'two dogs are running through the snow', 'two dogs are running through the snow', 'two dogs are running through the snow', 'two dogs are running through the snow']

# %% [markdown]
# Split the output back into tokens:

# %%
str_tokens = result.split()
str_tokens.append('[END]')

# %% [markdown]
# The `DecoderLayers` each cache the attention scores for their `CrossAttention` layer. The shape of each attention map is `(batch=1, heads, sequence, image)`:

# %%
attn_maps = [layer.last_attention_scores for layer in model.decoder_layers]
[map.shape for map in attn_maps]
# Out:
# [TensorShape([1, 2, 11, 49]), TensorShape([1, 2, 11, 49])]

# %% [markdown]
# So stack the maps along the `batch` axis, then average over the `(batch, heads)` axes, while splitting the `image` axis back into `height, width`:

# %%
attention_maps = tf.concat(attn_maps, axis=0)
attention_maps = einops.reduce(
    attention_maps,
    'batch heads sequence (height width) -> sequence height width',
    height=7, width=7,
    reduction='mean')

# %% [markdown]
# Now you have a single attention map, for each sequence prediction. The values in each map should sum to `1.`

# %%
einops.reduce(attention_maps, 'sequence height width -> sequence', reduction='sum')
# Out:
# <tf.Tensor: shape=(11,), dtype=float32, numpy=
# array([0.99999994, 0.99999994, 1.        , 1.        , 0.99999994,
#        1.        , 1.        , 1.        , 1.        , 0.99999994,
#        1.        ], dtype=float32)>

# %% [markdown]
# So here is where the model was focusing attention while generating each token of the output:

# %%
def plot_attention_maps(image, str_tokens, attention_map):
    fig = plt.figure(figsize=(16, 9))

    len_result = len(str_tokens)
    
    titles = []
    for i in range(len_result):
      map = attention_map[i]
      grid_size = max(int(np.ceil(len_result/2)), 2)
      ax = fig.add_subplot(3, grid_size, i+1)
      titles.append(ax.set_title(str_tokens[i]))
      img = ax.imshow(image)
      ax.imshow(map, cmap='gray', alpha=0.6, extent=img.get_extent(),
                clim=[0.0, np.max(map)])

    plt.tight_layout()

# %%
plot_attention_maps(image/255, str_tokens, attention_maps)

# %% [markdown]
# Now put that together into a more usable function:

# %%
@Captioner.add_method
def run_and_show_attention(self, image, temperature=0.0):
  result_txt = self.simple_generator(image, temperature)
  str_tokens = result_txt.split()
  str_tokens.append('[END]')

  attention_maps = [layer.last_attention_scores for layer in self.decoder_layers]
  attention_maps = tf.concat(attention_maps, axis=0)
  attention_maps = einops.reduce(
      attention_maps,
      'batch heads sequence (height width) -> sequence height width',
      height=7, width=7,
      reduction='mean')
  
  plot_attention_maps(image/255, str_tokens, attention_maps)
  t = plt.suptitle(result_txt)
  t.set_y(1.05)

# %%
run_and_show_attention(model, image)

# %% [markdown]
# ## Try it on your own images
#
# For fun, below you're provided a method you can use to caption your own images with the model you've just trained. Keep in mind, it was trained on a relatively small amount of data, and your images may be different from the training data (so be prepared for strange results!)

# %%
testimage1 = imageLoadResize("./test_imgs/image_test_1.jpg")
testimage2 = imageLoadResize("./test_imgs/image_test_2.jpg")
testimage3 = imageLoadResize("./test_imgs/image_test_3.jpg")
testimage4 = imageLoadResize("./test_imgs/image_test_4.jpg")
testimage5 = imageLoadResize("./test_imgs/image_test_5.jpg")
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-84-62fc849ffa7f> in <cell line: 1>()
# ----> 1 testimage1 = imageLoadResize("./test_imgs/image_test_1.jpg")
#       2 testimage2 = imageLoadResize("./test_imgs/image_test_2.jpg")
#       3 testimage3 = imageLoadResize("./test_imgs/image_test_3.jpg")
#       4 testimage4 = imageLoadResize("./test_imgs/image_test_4.jpg")
#       5 testimage5 = imageLoadResize("./test_imgs/image_test_5.jpg")
#
# <ipython-input-13-271892d01996> in imageLoadResize(img_path)
#       1 def imageLoadResize(img_path):
# ----> 2     img = tf.io.read_file(img_path)
#       3     img = tf.io.decode_jpeg(img, channels=3)
#       4     img = tf.image.resize(img, IMAGE_SHAPE[:-1])
#       5     return img
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/io_ops.py in read_file(filename, name)
#     131     A tensor of dtype "string", with the file contents.
#     132   """
# --> 133   return gen_io_ops.read_file(filename, name)
#     134
#     135
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gen_io_ops.py in read_file(filename, name)
#     579       pass
#     580     try:
# --> 581       return read_file_eager_fallback(
#     582           filename, name=name, ctx=_ctx)
#     583     except _core._SymbolicException:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gen_io_ops.py in read_file_eager_fallback(filename, name, ctx)
#     602   _inputs_flat = [filename]
#     603   _attrs = None
# --> 604   _result = _execute.execute(b"ReadFile", 1, inputs=_inputs_flat,
#     605                              attrs=_attrs, ctx=ctx, name=name)
#     606   if _execute.must_record_gradient():
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# NotFoundError: {{function_node __wrapped__ReadFile_device_/job:localhost/replica:0/task:0/device:CPU:0}} ./test_imgs/image_test_1.jpg; No such file or directory [Op:ReadFile]

# %%
run_and_show_attention(model, testimage1)

# %%
run_and_show_attention(model, testimage2)

# %%
run_and_show_attention(model, testimage3)

# %%
run_and_show_attention(model, testimage4)

# %%
run_and_show_attention(model, testimage5)
